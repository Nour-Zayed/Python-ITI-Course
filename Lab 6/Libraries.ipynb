# %%
"""
Problem 1:  
Create your own module file calculator.py with functions: add, subtract, multiply, divide. Then write another file that imports and uses all these functions. 
"""

# %%
"""Problem 2: 

Create a simple utility module with three functions: one that generates a random password, one that validates email, and one that formats phone numbers. Import specific functions using from module import function. """
