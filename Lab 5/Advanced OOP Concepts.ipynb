# %%
"""
Create a class Calculator with:
static method add(a, b)
static method multiply(a, b)
then call them
"""
class Calculator:

    @staticmethod
    def add(a, b):
        return a + b

    @staticmethod
    def multiply(a, b):
        return a * b


print(Calculator.add(5, 3))
print(Calculator.multiply(5, 3))
# Out:
# 8
# 15

# %%
"""MRO (Method Resolution Order)"""

class A:
    def show(self):
        print("A.show()")

class B(A):
    def show(self):
        print("B.show()")
        super().show()

class C(A):
    def show(self):
        print("C.show()")
        super().show()

class D(B, C):
    def show(self):
        print("D.show()")
        super().show()


d = D()
d.show()

print(D.mro())
# Out:
# D.show()
# B.show()
# C.show()
# A.show()
# [<class '__main__.D'>, <class '__main__.B'>, <class '__main__.C'>, <class '__main__.A'>, <class 'object'>]

# %%
#### Composition

class Engine:
    def __init__(self):
        print("Engine created")

    def start(self):
        print("Engine started")

    def __del__(self):
        print("Engine deleted")


class Car:
    def __init__(self, brand):
        self.brand = brand
        self.engine = Engine()  
        print(f"Car {brand} created")

    def start_car(self):
        self.engine.start()

    def __del__(self):
        print("Car deleted")


my_car = Car("Toyota")
my_car.start_car()

del my_car
# Out:
# Engine created
# Car Toyota created
# Engine started
# Car deleted
# Engine deleted

# %%
### Problem 4: Association

class Book:
    def __init__(self, title):
        self.title = title


class Library:
    def __init__(self):
        self.books = []

    def add_book(self, book):
        self.books.append(book)

    def remove_book(self, title):
        self.books = [b for b in self.books if b.title != title]

    def search(self, keyword):
        return [b.title for b in self.books if keyword.lower() in b.title.lower()]

    def list_books(self):
        return [b.title for b in self.books]
    
library = Library()
library.add_book(Book("Python Guide"))
library.add_book(Book("OOP with Python"))

print(library.search("Python"))
print(library.list_books())
# Out:
# ['Python Guide', 'OOP with Python']
# ['Python Guide', 'OOP with Python']

# %%
class Temperature:
    def __init__(self, celsius):
        self._celsius = celsius

    @property
    def celsius(self):
        return self._celsius

    @celsius.setter
    def celsius(self, value):
        self._celsius = value

    @property
    def fahrenheit(self):
        return (self._celsius * 9/5) + 32
temp = Temperature(25)
print(temp.fahrenheit)

temp.celsius = 30
print(temp.fahrenheit)
# Out:
# 77.0
# 86.0
